# %% [markdown]
# # (Ford GoBike System Data)
# ## by (Abdulhamead almania)
#
# ## Preliminary Wrangling
#
#
# ##### The Data(Ford GoBike dataset) Come From (https://www.lyft.com/bikes/bay-wheels) And The Main Goal To Find The Relationship Between Labels To Improve The Profit, In This Project We Will Tray To Find Way To Attracting And Retaining New Clients
#
# ##### Database :
#
# ###### The Dataset include a 2.5M rows and 10k unique pike for 11 month from 1 - 11, 330 days in 2019,The Dataset has a Like 350 unique station, The Dataset has 14 columns Shown below:
#
#
# duration_sec
#
# start_time
#
# end_time
#
# start_station_id
#
# start_station_name
#
# start_station_latitude
#
# start_station_longitude
#
# end_station_id
#
# end_station_name
#
# end_station_latitude
#
# end_station_longitude
#
# bike_id
#
# user_type (Subscriber or Customer – “Subscriber” = Member or “Customer” = Casual)
#
# bike_share_for_all_trip

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Gathering data
# In our task, we have multiple database wee need to be joined together for full year’s coverage

# %% [markdown]
# ### reading the data :
#
# ## code :

# %%
#READING THE DATA 
df1 = pd.read_csv('201901-fordgobike-tripdata.csv', sep = ";")

# %% [markdown]
# ## Test :

# %%
#TEST IF DATA IS LODE
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192082 entries, 0 to 192081
# Data columns (total 14 columns):
# duration_sec               192082 non-null int64
# start_time                 192082 non-null object
# end_time                   192082 non-null object
# start_station_id           191834 non-null float64
# start_station_name         191834 non-null object
# start_station_latitude     192082 non-null float64
# start_station_longitude    192082 non-null float64
# end_station_id             191834 non-null float64
# end_station_name           191834 non-null object
# end_station_latitude       192082 non-null float64
# end_station_longitude      192082 non-null float64
# bike_id                    192082 non-null int64
# user_type                  192082 non-null object
# bike_share_for_all_trip    192082 non-null object
# dtypes: float64(6), int64(2), object(6)
# memory usage: 20.5+ MB

# %% [markdown]
# ### continuing reading the data :
#
# ## code :

# %%
#READING ALL DATA 
df2  = pd.read_csv('201902-fordgobike-tripdata.csv', sep = ";")
df3  = pd.read_csv('201903-fordgobike-tripdata.csv', sep = ";")
df4  = pd.read_csv('201904-fordgobike-tripdata.csv', sep = ";")
df5  = pd.read_csv('201905-baywheels-tripdata.csv', sep = ";")
df6  = pd.read_csv('201906-baywheels-tripdata.csv', sep = ";")
df7  = pd.read_csv('201907-baywheels-tripdata.csv', sep = ";")
df8  = pd.read_csv('201908-baywheels-tripdata.csv', sep = ";")
df9  = pd.read_csv('201909-baywheels-tripdata.csv', sep = ";")
df10 = pd.read_csv('201910-baywheels-tripdata.csv', sep = ";")
df11 = pd.read_csv('201911-baywheels-tripdata.csv', sep = ";")

# %% [markdown]
# ## Test :

# %%
#TEST IF THE DATA IS LODE
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 14 columns):
# duration_sec               183412 non-null int64
# start_time                 183412 non-null object
# end_time                   183412 non-null object
# start_station_id           183215 non-null float64
# start_station_name         183215 non-null object
# start_station_latitude     183412 non-null float64
# start_station_longitude    183412 non-null float64
# end_station_id             183215 non-null float64
# end_station_name           183215 non-null object
# end_station_latitude       183412 non-null float64
# end_station_longitude      183412 non-null float64
# bike_id                    183412 non-null int64
# user_type                  183412 non-null object
# bike_share_for_all_trip    183412 non-null object
# dtypes: float64(6), int64(2), object(6)
# memory usage: 19.6+ MB

# %%
#TEST 
df10.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         62337  2019-10-31 16:25:01.5970  2019-11-01 09:43:59.0290
# 1         72610  2019-10-31 13:04:11.1950  2019-11-01 09:14:21.8050
# 2         56636  2019-10-31 17:17:37.6480  2019-11-01 09:01:33.7720
# 3         42250  2019-10-31 20:11:11.1270  2019-11-01 07:55:21.7440
# 4         40076  2019-10-31 18:48:32.1410  2019-11-01 05:56:28.4670
#
#    start_station_id        start_station_name  start_station_latitude  \
# 0               148      Horton St at 40th St               37.829705
# 1               376    Illinois St at 20th St               37.760458
# 2               453      Brannan St at 4th St               37.777934
# 3               182  19th Street BART Station               37.809369
# 4               237    Fruitvale BART Station               37.775232
#
#    start_station_longitude  end_station_id  \
# 0              -122.287610             385
# 1              -122.387540              30
# 2              -122.396973             453
# 3              -122.267951             163
# 4              -122.224498             237
#
#                                  end_station_name  end_station_latitude  \
# 0                     Woolsey St at Sacramento St             37.850578
# 1  San Francisco Caltrain (Townsend St at 4th St)             37.776598
# 2                            Brannan St at 4th St             37.777934
# 3                       Lake Merritt BART Station             37.797320
# 4                          Fruitvale BART Station             37.775232
#
#    end_station_longitude  bike_id   user_type bike_share_for_all_trip
# 0            -122.278175    12222    Customer                      No
# 1            -122.395282      282    Customer                      No
# 2            -122.396973    10940    Customer                      No
# 3            -122.265320    12623  Subscriber                      No
# 4            -122.224498     2601    Customer                      No

# %% [markdown]
# ## here i start to merge the data.
#
# ## Code :

# %%
#MERGE THE DATA 
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11])
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Test :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356881 entries, 0 to 185495
# Data columns (total 15 columns):
# bike_id                    int64
# bike_share_for_all_trip    object
# duration_sec               int64
# end_station_id             float64
# end_station_latitude       float64
# end_station_longitude      float64
# end_station_name           object
# end_time                   object
# rental_access_method       object
# start_station_id           float64
# start_station_latitude     float64
# start_station_longitude    float64
# start_station_name         object
# start_time                 object
# user_type                  object
# dtypes: float64(6), int64(2), object(7)
# memory usage: 287.7+ MB

# %%
#USE HIST TO CREATE A HISTOGRAM 
df.hist(figsize=(17,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000166F8C057B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166D4B6D780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166D4B9A8D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000166D4BCDA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166D4BFFB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166D4C30CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000166DFF90E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166DFFC5F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166DFFC5FD0>]],
#       dtype=object)

# %%
df.head()
# Out:
#    bike_id bike_share_for_all_trip  duration_sec  end_station_id  \
# 0     4861                      No         80825           196.0
# 1     5506                      No         65900           134.0
# 2     2717                      No         62633           157.0
# 3     4557                      No         44680            53.0
# 4     2100                      No         60709            28.0
#
#    end_station_latitude  end_station_longitude              end_station_name  \
# 0             37.808894            -122.256460       Grand Ave at Perkins St
# 1             37.752428            -122.420628        Valencia St at 24th St
# 2             37.846784            -122.291376          65th St at Hollis St
# 3             37.775946            -122.437777        Grove St at Divisadero
# 4             37.787168            -122.388098  The Embarcadero at Bryant St
#
#                    end_time rental_access_method  start_station_id  \
# 0  2019-02-01 16:24:49.8640                  NaN             229.0
# 1  2019-02-01 15:16:54.1730                  NaN               4.0
# 2  2019-02-01 11:30:46.5300                  NaN             245.0
# 3  2019-02-01 08:10:50.3180                  NaN              85.0
# 4  2019-02-01 07:10:51.0650                  NaN              16.0
#
#    start_station_latitude  start_station_longitude  \
# 0               37.775745              -122.213037
# 1               37.785881              -122.408915
# 2               37.870139              -122.268422
# 3               37.770083              -122.429156
# 4               37.794130              -122.394430
#
#             start_station_name                start_time   user_type
# 0    Foothill Blvd at 42nd Ave  2019-01-31 17:57:44.6130  Subscriber
# 1  Cyril Magnin St at Ellis St  2019-01-31 20:58:33.8860  Subscriber
# 2       Downtown Berkeley BART  2019-01-31 18:06:52.9240    Customer
# 3      Church St at Duboce Ave  2019-01-31 19:46:09.7190    Customer
# 4      Steuart St at Market St  2019-01-31 14:19:01.5410    Customer

# %%
#SHAPE OF DATA 
df.shape[0]
# Out:
# 2356881

# %%
#DESCRIBE OF DATA 
df.describe()
# Out:
#             bike_id  duration_sec  end_station_id  end_station_latitude  \
# count  2.356881e+06  2.356881e+06    2.295326e+06          2.356881e+06
# mean   2.340328e+04  8.087309e+02    1.418893e+02          3.776645e+01
# std    1.030756e+05  1.898050e+03    1.203936e+02          2.147563e-01
# min    4.000000e+00  6.000000e+01    3.000000e+00          0.000000e+00
# 25%    1.891000e+03  3.590000e+02    4.300000e+01          3.777008e+01
# 50%    3.799000e+03  5.710000e+02    1.010000e+02          3.778076e+01
# 75%    7.144000e+03  8.870000e+02    2.390000e+02          3.779639e+01
# max    9.999370e+05  8.621700e+04    4.930000e+02          4.551000e+01
#
#        end_station_longitude  start_station_id  start_station_latitude  \
# count           2.356881e+06      2.297166e+06            2.356881e+06
# mean           -1.223485e+02      1.453971e+02            3.776701e+01
# std             6.258700e-01      1.211839e+02            1.352916e-01
# min            -1.225143e+02      3.000000e+00            0.000000e+00
# 25%            -1.224117e+02      4.700000e+01            3.776976e+01
# 50%            -1.223981e+02      1.040000e+02            3.778053e+01
# 75%            -1.222935e+02      2.410000e+02            3.779539e+01
# max             0.000000e+00      4.930000e+02            4.551000e+01
#
#        start_station_longitude
# count             2.356881e+06
# mean             -1.223515e+02
# std               3.157512e-01
# min              -1.225143e+02
# 25%              -1.224130e+02
# 50%              -1.223983e+02
# 75%              -1.222934e+02
# max               0.000000e+00

# %%
#MAKE SHORE IF THERE ANY NULL VALUE
df.isnull().sum()
# Out:
# bike_id                          0
# bike_share_for_all_trip      93157
# duration_sec                     0
# end_station_id               61555
# end_station_latitude             0
# end_station_longitude            0
# end_station_name             61005
# end_time                         0
# rental_access_method       2263724
# start_station_id             59715
# start_station_latitude           0
# start_station_longitude          0
# start_station_name           59118
# start_time                       0
# user_type                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# bike_id                      int64
# bike_share_for_all_trip     object
# duration_sec                 int64
# end_station_id             float64
# end_station_latitude       float64
# end_station_longitude      float64
# end_station_name            object
# end_time                    object
# rental_access_method        object
# start_station_id           float64
# start_station_latitude     float64
# start_station_longitude    float64
# start_station_name          object
# start_time                  object
# user_type                   object
# dtype: object

# %% [markdown]
# ## Make a Copy of Data
#
# ## Code :

# %%
#MAKE A COPY FORM THE DATA 
df_copy = df.copy()

# %% [markdown]
# ## Drop Unwanted Columns
#
# ## Code :

# %%
#DROP UN WANTED COLUMNS 
df_copy.drop(['start_station_latitude','start_station_longitude','rental_access_method','end_station_latitude','end_station_longitude'], axis=1, inplace=True)

# %% [markdown]
# ## Test :

# %%
df_copy.dtypes
# Out:
# bike_id                      int64
# bike_share_for_all_trip     object
# duration_sec                 int64
# end_station_id             float64
# end_station_name            object
# end_time                    object
# start_station_id           float64
# start_station_name          object
# start_time                  object
# user_type                   object
# dtype: object

# %%
#CHEAK HOW MANY UNUQUE BIKE ID IN THE DATA 
df_copy.bike_id.nunique()
# Out:
# 10875

# %% [markdown]
# ## Drop the null Value
# ## Code :

# %%
#DROP THE NULL VALUE
df_clean = df_copy.dropna(axis = 0, how ='any')

# %% [markdown]
# ## Test :

# %%
df_clean.isnull().sum()
# Out:
# bike_id                    0
# bike_share_for_all_trip    0
# duration_sec               0
# end_station_id             0
# end_station_name           0
# end_time                   0
# start_station_id           0
# start_station_name         0
# start_time                 0
# user_type                  0
# dtype: int64

# %%
df_clean.shape[0]
# Out:
# 2262979

# %%
df_clean.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000166E0086E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166A3FA0DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000166A3FCBEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000166E6EAC080>]],
#       dtype=object)

# %% [markdown]
# ## Create New Columns Based On Duration Columns From Sec To Min
# ## Code :

# %%
#CREAT A NEW COLUMNS FORM 'duration_sec'
df_clean['duration_min'] = df_clean['duration_sec'] / 60
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_clean.head(1)
# Out:
#    bike_id bike_share_for_all_trip  duration_sec  end_station_id  \
# 0     4861                      No         80825           196.0
#
#           end_station_name                  end_time  start_station_id  \
# 0  Grand Ave at Perkins St  2019-02-01 16:24:49.8640             229.0
#
#           start_station_name                start_time   user_type  \
# 0  Foothill Blvd at 42nd Ave  2019-01-31 17:57:44.6130  Subscriber
#
#    duration_min
# 0   1347.083333

# %% [markdown]
# ## Chane Data Type Of start_time and end_time To Timestamp
# ## Code :

# %%
#CHANGE THE DATA TYPE OF 'start_time' AND 'end_time'
df_clean['start_time']=pd.to_datetime(df_clean['start_time'])
df_clean['end_time']=pd.to_datetime(df_clean['end_time'])
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2262979 entries, 0 to 184085
# Data columns (total 11 columns):
# bike_id                    int64
# bike_share_for_all_trip    object
# duration_sec               int64
# end_station_id             float64
# end_station_name           object
# end_time                   datetime64[ns]
# start_station_id           float64
# start_station_name         object
# start_time                 datetime64[ns]
# user_type                  object
# duration_min               float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(4)
# memory usage: 207.2+ MB

# %% [markdown]
# ## Create New Columns Based On Data Columns To Week Day Names  For Start Time and End Time Traffic
# ## Code :

# %%
#CREATE A NEW COLUMNS FORM 'start_time' AND 'end_time' FOR WEEK DAY 
df_clean['start_time_weekday']=df_clean['start_time'].dt.weekday_name
df_clean['end_time_weekday']=df_clean['end_time'].dt.weekday_name
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Test :

# %%
df_clean.head(1)
# Out:
#    bike_id bike_share_for_all_trip  duration_sec  end_station_id  \
# 0     4861                      No         80825           196.0
#
#           end_station_name                end_time  start_station_id  \
# 0  Grand Ave at Perkins St 2019-02-01 16:24:49.864             229.0
#
#           start_station_name              start_time   user_type  \
# 0  Foothill Blvd at 42nd Ave 2019-01-31 17:57:44.613  Subscriber
#
#    duration_min start_time_weekday end_time_weekday
# 0   1347.083333           Thursday           Friday

# %%
# SEE HOW MANY TIME USED IN WEEKDAY 
df_clean['end_time_weekday'].value_counts()
# Out:
# Thursday     387942
# Tuesday      382672
# Wednesday    381536
# Friday       359366
# Monday       352366
# Saturday     209838
# Sunday       189259
# Name: end_time_weekday, dtype: int64

# %% [markdown]
# ## Create New Columns Based On Data Columns To Only Dates  For Start Time and End Time Traffic
# ## Code :

# %%
#USE A 'dt.date' FUNCTIEN TO CREATE A NEW COLUMNS FOR DATE TIME 
df_clean['start_time_date']=df_clean['start_time'].dt.date
df_clean['end_time_date']=df_clean['end_time'].dt.date
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Test :

# %%
df_clean.head(1)
# Out:
#    bike_id bike_share_for_all_trip  duration_sec  end_station_id  \
# 0     4861                      No         80825           196.0
#
#           end_station_name                end_time  start_station_id  \
# 0  Grand Ave at Perkins St 2019-02-01 16:24:49.864             229.0
#
#           start_station_name              start_time   user_type  \
# 0  Foothill Blvd at 42nd Ave 2019-01-31 17:57:44.613  Subscriber
#
#    duration_min start_time_weekday end_time_weekday start_time_date  \
# 0   1347.083333           Thursday           Friday      2019-01-31
#
#   end_time_date
# 0    2019-02-01

# %%
df_clean['start_time_date'].nunique()
# Out:
# 334

# %% [markdown]
# ## Create New Columns Based On Data Columns To Only Month  For Start Time and End Time Traffic
# ## Code :

# %%
#CREATE A NEW COLUMNS USEING 'dt.month' FUNCTIEN TO CREATE A TIME FOR MONTH
df_clean['start_time_month']=df_clean['start_time'].dt.month.astype(int)
df_clean['end_time_month']=df_clean['end_time'].dt.month.astype(int)
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Test :

# %%
df_clean['start_time_month'].value_counts()
# Out:
# 3     256078
# 10    239895
# 4     239047
# 9     217986
# 8     210563
# 1     191834
# 6     187879
# 11    184086
# 2     183215
# 5     182148
# 7     170248
# Name: start_time_month, dtype: int64

# %% [markdown]
# ## Create New Columns Based On Data Columns To Only Hour  For Start Time and End Time Traffic
# ## Code :

# %%
#CREATE A NEW COLUMNS USEING 'dt.hour' FUNCTIEN TO CREATE A TIME FOR hour
df_clean['start_time_hour']=df_clean['start_time'].dt.hour
df_clean['end_time_hour']=df_clean['end_time'].dt.hour
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Test :

# %%
df_clean['start_time_hour'].value_counts()
# Out:
# 17    272199
# 8     254081
# 18    214799
# 9     195725
# 16    173949
# 19    131116
# 7     128861
# 15    110900
# 12    101376
# 13     99343
# 10     98110
# 14     95944
# 11     91490
# 20     83057
# 21     58533
# 6      48423
# 22     39427
# 23     23275
# 0      12758
# 5      11968
# 1       7486
# 2       4803
# 4       2987
# 3       2369
# Name: start_time_hour, dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2262979 entries, 0 to 184085
# Data columns (total 19 columns):
# bike_id                    int64
# bike_share_for_all_trip    object
# duration_sec               int64
# end_station_id             float64
# end_station_name           object
# end_time                   datetime64[ns]
# start_station_id           float64
# start_station_name         object
# start_time                 datetime64[ns]
# user_type                  object
# duration_min               float64
# start_time_weekday         object
# end_time_weekday           object
# start_time_date            object
# end_time_date              object
# start_time_month           int32
# end_time_month             int32
# start_time_hour            int64
# end_time_hour              int64
# dtypes: datetime64[ns](2), float64(3), int32(2), int64(4), object(8)
# memory usage: 328.0+ MB

# %%
print(df_clean.describe())
# Out:
#             bike_id  duration_sec  end_station_id  start_station_id  \
# count  2.262979e+06  2.262979e+06    2.262979e+06      2.262979e+06
# mean   4.796712e+03  8.069304e+02    1.415932e+02      1.451120e+02
# std    3.692328e+03  1.922206e+03    1.202948e+02      1.210959e+02
# min    4.000000e+00  6.100000e+01    3.000000e+00      3.000000e+00
# 25%    1.827000e+03  3.580000e+02    4.300000e+01      4.700000e+01
# 50%    3.625000e+03  5.690000e+02    1.010000e+02      1.040000e+02
# 75%    6.486000e+03  8.840000e+02    2.390000e+02      2.410000e+02
# max    1.311200e+04  8.621700e+04    4.930000e+02      4.930000e+02
#
#        duration_min  start_time_month  end_time_month  start_time_hour  \
# count  2.262979e+06      2.262979e+06    2.262979e+06     2.262979e+06
# mean   1.344884e+01      6.002137e+00    6.002211e+00     1.354237e+01
# std    3.203676e+01      3.159159e+00    3.159161e+00     4.799467e+00
# min    1.016667e+00      1.000000e+00    1.000000e+00     0.000000e+00
# 25%    5.966667e+00      3.000000e+00    3.000000e+00     9.000000e+00
# 50%    9.483333e+00      6.000000e+00    6.000000e+00     1.400000e+01
# 75%    1.473333e+01      9.000000e+00    9.000000e+00     1.700000e+01
# max    1.436950e+03      1.100000e+01    1.200000e+01     2.300000e+01
#
#        end_time_hour
# count   2.262979e+06
# mean    1.370721e+01
# std     4.823762e+00
# min     0.000000e+00
# 25%     9.000000e+00
# 50%     1.400000e+01
# 75%     1.800000e+01
# max     2.300000e+01

# %% [markdown]
# ## Save The Dataset after Cleaning
#
# ## Code :

# %%
#DAVE THE DATA AS CSV.
df_clean.to_csv("final_data.csv")/`

# %% [markdown]
# ### What is the structure of your dataset?
#
# The current data set of 11'csv' files, representing each month of the year(2019),there are 2,262,979 rows in this dataset and 20 features.
#
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# duration min, bike share for all trip, station names, user type, and Dates
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# bike id and bike share for all trip, end station name, start station name, user type, duration min, start time weekday, start time date, start time month, start time_hour

# %% [markdown]
# ## Univariate Exploration
#
# > In this section we investigate distributions of individual variables

# %%
#PLOT A 'start_time_month'COLUMNS 
binsize = 1
bins = np.arange(0, df_clean['start_time_month'].max()+binsize, binsize)
plt.figure(figsize=[10, 6])#SET A FIGURE SIZE 
plt.hist(data = df_clean, x = 'start_time_month', bins = bins)
plt.xlabel('Month') #SET X LABEL
plt.title("The Number Of Trips In Months")#SET TITLE
plt.ylabel('Number Of Trips') #SET Y LABEL
plt.show();

# %% [markdown]
# ##### Here We Can See In Last Month Has Increasing On Trips It's Almost A Double Last Month, Maybe Tha Company It Spread Among People, Either By Advertising Or In Some Other Way.

# %%
binsize = 1
bins = np.arange(0, df_clean['start_time_hour'].max()+binsize, binsize)
plt.figure(figsize=[10, 6])#SET FIGURE SIZE 
plt.hist(data = df_clean, x = 'start_time_hour', bins = bins)
plt.xlabel('The time')#SET X LABEL
plt.title("When Do Trip Start (Hour / 24)")#SET TITLE
plt.ylabel('Number Of Trips') #SET Y LABEL
plt.show()
#######
bins = np.arange(0, df_clean['end_time_hour'].max()+binsize, binsize)
plt.figure(figsize=[10, 6])#SET FIGURE SIZE 
plt.hist(data = df_clean, x = 'end_time_hour', bins = bins)
plt.xlabel('The time')#SET X LABEL
plt.title("When Do Trip End (Hour / 24)")#SET TITLE
plt.ylabel('Number Of Trips')#SET Y LABEL
plt.show();

# %% [markdown]
# ###### Here We Can See The Rush Hours Has Most Trip From 7-10 and 15-20,It May Be Because It Is Time To Work In These Areas,Of Course, We Only Notice A Very Slight Difference Between The Start And End Times Of The Trip.

# %%
binsize = 1
bins = np.arange(0, df_clean['duration_sec'].max()+50, 50)
plt.figure(figsize=[10, 6])# SET FIGURE SIZE
plt.hist(data = df_clean, x = 'duration_sec', bins = bins)
plt.xlim(0,3500) # to set a limt 
plt.xlabel('Duration') #SET X LABEL
plt.title("Shows How Long The Average Trips Takes In Seconds")#SET TITLE
plt.ylabel('Number Of Trips')#SET Y LABEL
plt.show()
#######
bins = np.arange(0, df_clean['duration_min'].max()+50, 50)
plt.figure(figsize=[10, 6])# SET FIGURE SIZE
plt.hist(data = df_clean, x = 'duration_min', bins = bins)
plt.xlim(0,200) # to set a limt 
plt.xlabel('Duration')#SET X LABEL
plt.title("Shows How Long The Average Trips Takes In Minutes")#SET TITLE
plt.ylabel('Number Of Trips')#SET Y LABEL
plt.show();

# %% [markdown]
# ###### We See The Difference Between Trips In Terms Of Time Taken, So We Find That Most Trips Are Between One To Twenty-Five Minutes, The Reason May Be That Most Of The Users Live Near To The Intended Area, And The Company Also Takes More Money If The Service Uses More Than Forty Five Minutes Also, Note That There Are Few People Who Travel Long Distances / Use Them Longer

# %%
plt.figure(figsize = [9, 9])#SET FIGURE SIZE
sb.countplot(data=df_clean,x='bike_share_for_all_trip')
plt.xlabel('Bike Share For All Trip')#SET X LABEL
plt.ylabel('Trips')#SET Y LABEL
plt.show();

# %% [markdown]
# ###### The (Bike Share For All Trip) Is A Offer All Residents Of The Bay Area An Affordable, Accessible, And Fun new Transportation Option. Bike Share For All Provides A One-Time $ 5 Annual Membership For Qualifying Residents, But a Few Customers In This Subscription ,Why ? Fate Is Due To The Nature Of This Service Or It Is A New Service

# %%
plt.figure(figsize = [9, 9])#SET FIGURE SIZE
sb.countplot(data=df_clean,x='user_type')
plt.xlabel('User Type')#SET X LABEL
plt.ylabel('Trips')#SET Y LABEL
plt.show();

# %%
# list of days in order
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# change weekday variable to ordered categorical variable
df_clean['start_time_weekday'] = pd.Categorical(df_clean['start_time_weekday'],
                                              categories=day_order,
                                              ordered = True)
# Out:
# C:\Users\www7m\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# ###### We Can See Is a Few Is A New Customer And Not Subscribed, The Company Must Find A Solution To Make Them Subscribers Or Permanent Customers Through Offers Or Discounts For New Customers.

# %%
plt.figure(figsize = [9, 9])#SET FIGURE SIZE
sb.countplot(data=df_clean,x='start_time_weekday')
plt.xlabel('Start time(weekday)')#SET X LABEL
plt.ylabel('duration (min)')#SET Y LABEL
plt.show();

# %% [markdown]
# ###### We Can See In Weekend(Sunday and Saturday) The Trip is Going Down, There May Be A Solution To Increasing The Number Of Trips, Such As Placing A Special Weekend Discount Or A Special Offer To Get People Excited.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > I'm Supposed To Convert Some Variable Like Day, Month, and Time, But I Already Got That One Step Earlier
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Bike Share For All Trip Is A Special Offer But Its Has A Few People They Are Subscripts

# %% [markdown]
# ## Bivariate Exploration
#
# >In this section,  we investigate relationships between pairs of variables in our data.

# %%
samples = np.random.choice(df_clean.shape[0], 500, replace = False)#TAKE A SAMPLE FOR DATA 
df_clean_samp = df_clean.loc[samples,:]

g = sb.PairGrid(data = df_clean_samp)
g = g.map_diag(plt.hist, bins = 20);
g.map_offdiag(plt.scatter);

# %% [markdown]
# ###### Best Way To Start To Find The Relationship Is Use A Scatter Plot

# %%
plt.figure(figsize = [10,10])#SET FIGURE SIZE
plt.scatter(data = df_clean , x = 'start_time_month' , y = 'duration_min' , alpha = 0.1 )
plt.title('Monthly Trip Duration')#SET TITLE
plt.xlabel('Month')#SET X LABEL
#SET Y LABEL
plt.ylabel('Trip(Minutes)');

# %% [markdown]
# ###### We Can See The Who Take Longer Duration Of Each Month And They Almost The Same

# %%
plt.figure(figsize = [10,10])#SET FIGURE SIZE
plt.scatter(data = df_clean , x = 'start_time_weekday' , y = 'duration_min' , alpha = 0.08 )
plt.title('Weekday Trip Duration')#SET TITLE
plt.xlabel('Days')#SET X LABEL
#SET Y LABEL
plt.ylabel('Trip(Minutes)');

# %% [markdown]
# ###### We Can See The Who Take Longer Duration Of Each Week Days And They Almost The Same

# %%
plt.figure(figsize = [4,13])#SET FIGURE SIZE
plt.scatter(data = df_clean , x = 'user_type' , y = 'duration_min' , alpha = 0.1 )
plt.title('User Type Trip Duration')#SET TITLE
plt.xlabel('User Type')#SET X LABEL
#SET Y LABEL
plt.ylabel('Trip(Minutes)');

# %% [markdown]
# ###### We Can See The Customer They Take Duration More Than Subscriber

# %%
plt.figure(figsize = [4,12])#SET FIGURE SIZE
plt.scatter(data = df_clean , x = 'bike_share_for_all_trip' , y = 'duration_min' , alpha = 0.3 )
plt.title('Bike Share For All Trip Duration')#SET TITLE
plt.xlabel('Bike ShareF For All Trip')#SET X LABEL
#SET Y LABEL
plt.ylabel('Trip(Minutes)');

# %% [markdown]
# ###### We Can See The Trips Who Take The Special Offer They Take Less Than Duration

# %%
plt.figure(figsize = [9, 9])#SET FIGURE SIZE
sb.barplot(data = df_clean, x = 'start_time_weekday', y = 'duration_min', palette = 'Blues')
plt.ylabel('Duration[Min]'.title(),fontsize = 10, weight = "bold") #SET Y LABEL
plt.xlabel('Time Start[Weekday]'.title(),fontsize = 10, weight = "bold")#SET X LABEL
plt.show();

# %% [markdown]
# ###### We Can See In Sunday And Saturday They had The Most Late To Start (But In Previous Graphic is Has A The Lowest Number Of Trips)

# %%
plt.figure(figsize = [9, 9])#SET FIGURE SIZE
sb.barplot(data = df_clean, x = 'start_time_month', y = 'duration_min', palette = 'hls')
plt.ylabel('Duration[Min]'.title(),fontsize = 10, weight = "bold")#SET Y LABEL
plt.xlabel('Time Start[Month]'.title(),fontsize = 10, weight = "bold")#SET X LABEL

plt.show();

# %% [markdown]
# ###### Almost Every Month Has The Same Average Duration Of Time

# %%
df_clean.groupby('start_time_date').agg({'bike_id':'count'}).plot(legend=False, figsize=(14,8))#SET FIGUR SIZE
plt.title('All time Trip Duration In 2019')#SET TITLE
plt.xlabel('Year/Month')#SET X LABEL
#SET Y LABEL
plt.ylabel('Trip');

# %% [markdown]
# ###### We Can See After 2019-4 It Has Huge Decreased For Number Of Trips

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > There Is A Difference In Terms Of The Number Of Trips On Weekdays Such As Weekends And Times When People Start Using Bikes
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Duration and  Dates

# %% [markdown]
# ## Multivariate Exploration
#
# > we create plots of three or more variables to investigate in our data even further.

# %%
fig = plt.figure(figsize = [9,7])#SET FIGURE SIZE
ax = sb.pointplot(data = df_clean, x = 'start_time_month', y = 'duration_min', hue = 'user_type',
           palette = 'deep', linestyles = '', dodge = 0.4)
plt.title('')#SET TITLE
plt.ylabel('Duration[min]')#SET Y LABEL
plt.xlabel('Month')#SET X LABEL
plt.yscale('log')
plt.legend(title='User Type')#SET LEGEND TITLE
plt.yticks([10, 11,15,20,25,30],['10', '11','15','20','25','30']) #SET Y TICKS
ax.set_yticklabels([],minor = True)
plt.show();

# %% [markdown]
# ###### We Can See The Customer They Take Duration More Than Subscriber

# %%
plt.figure(figsize = [11,10])# SET FIGURE SIZE

ax = sb.pointplot(data = df_clean, x = 'start_time_month', y = 'duration_min', hue = 'user_type')

plt.yscale('log')
plt.ylabel('Duration[min]')#SET Y LABEL
plt.xlabel('Month')#SET X LABEL
ax.set_yticklabels([], minor = True)
plt.yticks([10, 11,15,20,25,30],['10', '11','15','20','25','30'])#SET Y TICKS 
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
           title="User Type", title_fontsize = 12)#SET LEGEND TITLE
plt.show();
###
plt.figure(figsize = [11,10])#SET FIGURE SIZE
ax = sb.pointplot(data = df_clean, x = 'start_time_weekday', y = 'duration_min', hue = 'user_type')
plt.yscale('log')
plt.ylabel('Duration[min]')#SET Y LABEL
plt.xlabel('Week Day')#SET X LABEL
ax.set_yticklabels([], minor = True)
plt.yticks([10, 11,15,20,25,30],['10', '11','15','20','25','30'])#SET Y TICKS
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
           title="User Type", title_fontsize = 12)#SET LEGEND TITLE

plt.show();

# %% [markdown]
# ###### We Can See The Customer They Take Duration More Than Subscriber, We Can See In Sunday And Saturday They had The Longest Time For The Trip.

# %%
plt.figure(figsize = [10,8])# SET FIGURE SIZE

ax = sb.pointplot(data = df_clean, x = 'start_time_month', y = 'duration_min', hue = 'bike_share_for_all_trip')

# special handling of tick marks following seaborn function - you might try
# doing a log transform on the data itself instead of this workaround.
plt.yscale('log')
plt.ylabel('Duration[min]')#SET Y LABEL
plt.xlabel('Month')#SET X LABEL

ax.set_yticklabels([], minor = True)
plt.yticks([12,13,14, 15],['12','13','14','15'])#SET Y TICKS
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
           title="Bike Share For All Trip", title_fontsize = 12)#SET LEGEND NAME 

plt.show();

# %% [markdown]
# ###### We Can See The Trips Who Take The Special Offer They Take Less Than Duration  Each Month

# %%
g = sb.FacetGrid(data =  df_clean, hue = 'user_type', height = 8)
g.map(plt.scatter, 'start_time_month','duration_min', alpha = 1/3)
plt.title('Trip Duration(min) Against Month and User Type')#SET TITLE 
plt.xlabel('Month')#SET X LABEL
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
           title="User Type", title_fontsize = 12)#SET A LEGEND
#SET Y LABEL
plt.ylabel('Trip Duration(min)');

# %% [markdown]
# ###### We Can See The Customer They Take Duration More Than Subscriber, And It Almost The Same Each Month

# %%
g = sb.FacetGrid(data =  df_clean, hue = 'bike_share_for_all_trip', height = 8)
g.map(plt.scatter, 'start_time_month','duration_min', alpha = 1/3)
plt.title('Trip Duration(min) Against Month and User Type')#SET TITLE
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
           title="Bike Share For All Trip", title_fontsize = 12)#SET A LEGEND
plt.xlabel('Month')#SET X LABEL
#SET Y LABEL
plt.ylabel('Trip Duration(min)');

# %%
plt.figure(figsize=[14.70,8.27])#SET FIGURE SIZE
sns.stripplot(data = df_clean , hue = 'bike_share_for_all_trip',
           x = 'start_time_month' , y= 'duration_min' ,jitter = 0.35 , dodge = True)
plt.title('Trip Duration(min) Against Month and User Type'.title(),
         fontsize = 14 , weight = "bold")#SET A TITLE
plt.xlabel('Month'.title(),fontsize = 10 , weight = "bold")#SET X LABEL
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
           title="Bike Share For All Trip", title_fontsize = 12)#SET A LEGEND
#SET Y LABEL
plt.ylabel('Trip Duration(min)'.title(),fontsize = 10 , weight = "bold" );

# %% [markdown]
# ###### We Can See The Trips Who Take The Special Offer They Take Less Than Duration  Each Month

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > There Is A Difference In Terms Of The Number Of Trips On Weekdays Such As Weekends And Times When People Start Using Bikes Or The special Offer.
#
# > We Can See The Customer They Cut Off Duration Longer The Subscriber.
#
# > We Can See On Sunday And Saturday They had The Longest Time For The Trip.
#
# > We Can See The Most Trips is Short Term.
#
# > We Can See The Special Offer(bike share for all trip) The Number Of Users Is Not Stable.
#
# ### Were there any interesting or surprising interactions between features?
#
# > Duration and  Dates
